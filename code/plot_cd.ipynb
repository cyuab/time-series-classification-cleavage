# %%
import numpy as np
from aeon.visualisation import plot_critical_difference

# %% [markdown]
# # Channel ablation study

# %%
# classifiers = ["Baseline", "Baseline + SS", "Baseline + Base-pair probability (Standalone)", "Baseline + Base-pair probability (Incorporated)"]
classifiers = ["cfg 1", "cfg 2", "cfg 3", "cfg 4"]
classifier_accuracies_5p = [
    # 5p
    [0.781, 0.847, 0.842, 0.799], # ROCKET
    [0.755, 0.825, 0.817, 0.776], # MiniROCKET
    [0.784, 0.812, 0.822, 0.814], # MultiROCKET
    [0.830, 0.845, 0.846, 0.822], # Hydra
    [0.796, 0.817, 0.822, 0.814], # MultiROCKET-Hydra
]
plt, _ = plot_critical_difference(classifier_accuracies_5p, classifiers)
plt.savefig("../figures/channel_ablation_cd_5p.pdf", format="pdf", bbox_inches="tight")

# %%
classifier_accuracies_3p = [
    # 3p
    [0.790, 0.855, 0.855, 0.809], # ROCKET
    [0.788, 0.822, 0.836, 0.801], # MiniROCKET
    [0.803, 0.824, 0.825, 0.816], # MultiROCKET
    [0.808, 0.846, 0.851, 0.834], # Hydra
    [0.807, 0.825, 0.835, 0.820], # MultiROCKET-Hydra
]
plt, _ = plot_critical_difference(classifier_accuracies_3p, classifiers)
plt.savefig("../figures/channel_ablation_cd_3p.pdf", format="pdf", bbox_inches="tight")

# %%
classifiers = ["cfg 1", "cfg 2", "cfg 3", "cfg 4"]
classifier_accuracies_multi = [
    # Multi
    [0.717, 0.836, 0.795, 0.737], # ROCKET
    [0.685, 0.823, 0.772, 0.705], # MiniROCKET
    [0.691, 0.796, 0.758, 0.726], # MultiROCKET
    [0.731, 0.830, 0.789, 0.759], # Hydra
    [0.701, 0.803, 0.759, 0.736], # MultiROCKET-Hydra
]
plt, _ = plot_critical_difference(classifier_accuracies_multi, classifiers)
plt.savefig("../figures/channel_ablation_cd_multi.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# We will then include "Baseline", "SS", "Base-pair probability (Standalone)" as the multivariate time series.

# %% [markdown]
# # General the best classifier

# %%
classifiers = ["ROCKET", "MiniROCKET", "MultiROCKET", "Hydra", "MultiROCKET-Hydra"]
classifier_accuracies_5p = [
    # 5p
    [0.849, 0.823, 0.821, 0.843, 0.820], # Single Value Mapping
    [0.835, 0.843, 0.819, 0.825, 0.818], # Grouped Variable-Length Channel Mapping
    [0.851, 0.844, 0.831, 0.848, 0.836], # Grouped Fixed-Length Channel Mapping
    [0.850, 0.840, 0.822, 0.848, 0.824], # Cumulative Mapping
    [0.843, 0.845, 0.826, 0.850, 0.824], # Cumulative Grouped Variable-Length Channel Mapping
    [0.856, 0.856, 0.820, 0.850, 0.820], # Cumulative Grouped Fixed-Length Channel Mapping
    [0.850, 0.847, 0.827, 0.851, 0.829], # Global Cumulative Mapping
    [0.840, 0.848, 0.834, 0.857, 0.837], # Global Cumulative Grouped Variable-Length Channel Mapping
    [0.856, 0.857, 0.829, 0.856, 0.829], # Global Cumulative Grouped Fixed-Length Channel Mapping
]
plt, _ = plot_critical_difference(classifier_accuracies_5p, classifiers)
plt.savefig("../figures/best_classifier_cd_5p.pdf", format="pdf", bbox_inches="tight")

# %%
classifier_accuracies_3p = [
    # 3p
    [0.863, 0.823, 0.839, 0.838, 0.840], # Single Value Mapping
    [0.855, 0.831, 0.817, 0.811, 0.831], # Grouped Variable-Length Channel Mapping
    [0.863, 0.840, 0.824, 0.862, 0.833], # Grouped Fixed-Length Channel Mapping
    [0.863, 0.840, 0.832, 0.853, 0.838], # Cumulative Mapping
    [0.856, 0.836, 0.815, 0.834, 0.833], # Cumulative Grouped Variable-Length Channel Mapping
    [0.870, 0.842, 0.798, 0.855, 0.807], # Cumulative Grouped Fixed-Length Channel Mapping
    [0.863, 0.848, 0.847, 0.861, 0.843], # Global Cumulative Mapping
    [0.853, 0.841, 0.831, 0.822, 0.834], # Global Cumulative Grouped Variable-Length Channel Mapping
    [0.870, 0.840, 0.820, 0.859, 0.822], # Global Cumulative Grouped Fixed-Length Channel Mapping
    # [0.834, 0.831, 0.820, 0.816, 0.822], # Global Cumulative Grouped Variable-Length Channel Mapping Reverse testing
    # [0.865, 0.828, 0.821, 0.857, 0.822], # Global Cumulative Grouped Fixed-Length Channel Mapping Reverse testing
]
plt, _ = plot_critical_difference(classifier_accuracies_3p, classifiers)
plt.savefig("../figures/best_classifier_cd_3p.pdf", format="pdf", bbox_inches="tight")

# %%
classifier_accuracies_multi = [
    # multi
    [0.853, 0.835, 0.811, 0.831, 0.816], # Single Value Mapping
    [0.846, 0.837, 0.890, 0.818, 0.820], # Grouped Variable-Length Channel Mapping
    [0.849, 0.851, 0.811, 0.843, 0.828], # Grouped Fixed-Length Channel Mapping
    [0.852, 0.843, 0.820, 0.845, 0.821], # Cumulative Mapping
    [0.855, 0.840, 0.826, 0.833, 0.830], # Cumulative Grouped Variable-Length Channel Mapping
    [0.863, 0.845, 0.809, 0.847, 0.821], # Cumulative Grouped Fixed-Length Channel Mapping
    [0.852, 0.845, 0.825, 0.847, 0.832], # Global Cumulative Mapping
    [0.856, 0.844, 0.828, 0.826, 0.835], # Global Cumulative Grouped Variable-Length Channel Mapping
    [0.863, 0.844, 0.819, 0.846, 0.827], # Global Cumulative Grouped Fixed-Length Channel Mapping
]
plt, _ = plot_critical_difference(classifier_accuracies_multi, classifiers)
plt.savefig("../figures/best_classifier_cd_multi.pdf", format="pdf", bbox_inches="tight")

# %%
# classifier_accuracies_whole = classifier_accuracies_5p + classifier_accuracies_3p + classifier_accuracies_multi
# plt, _ = plot_critical_difference(classifier_accuracies_whole, classifiers)

# %% [markdown]
# In every category (5p, 3p, and multi), the ranking of the performances of these five classifiers is the same.

# %% [markdown]
# # Best encoding method

# %%
classifiers = ["enc 1", "enc 2", "enc 3", 
               "enc 4", "enc 5" , "enc 6", 
               "enc 7", "enc 8" , "enc 9"]
classifiers = ["Single value mapping", "Grouped variable-length channel mapping", "Grouped fixed-length channel mapping", 
               "Cumulative mapping", "Cumulative grouped variable-length channel mapping" , "Cumulative grouped fixed-length channel mapping", 
               "Global cumulative mapping", "Global cumulative grouped variable-length channel mapping" , "Global cumulative grouped fixed-length channel mapping"]
# transpose
plt, _ = plot_critical_difference(list(map(list, zip(*classifier_accuracies_5p))), classifiers)
plt.savefig("../figures/best_encoding_cd_5p.pdf", format="pdf", bbox_inches="tight")

# %%
# classifiers = ["Single value mapping", "Grouped variable-length channel mapping", "Grouped fixed-length channel mapping", 
#                "Cumulative mapping", "Cumulative grouped variable-length channel mapping" , "Cumulative grouped fixed-length channel mapping", 
#                "Global cumulative mapping", "Global cumulative grouped variable-length channel mapping" , "Global cumulative grouped fixed-length channel mapping", "diff reverse", "eq reverse"]
# transpose
plt, _ = plot_critical_difference(list(map(list, zip(*classifier_accuracies_3p))), classifiers)
plt.savefig("../figures/best_encoding_cd_3p.pdf", format="pdf", bbox_inches="tight")

# %%
# transpose
plt, _ = plot_critical_difference(list(map(list, zip(*classifier_accuracies_multi))), classifiers)
plt.savefig("../figures/best_encoding_cd_multi.pdf", format="pdf", bbox_inches="tight")

# %% [markdown]
# For all categories, the "Global cumulative" stands out. In the 5p dataset, the grouped version of "Global cumulative" improve the performance.

# %%
# # Normal
# classifiers = ["Single value mapping", "Grouped variable-length channel mapping", "Grouped fixed-length channel mapping", 
#                "Cumulative mapping", "Cumulative grouped variable-length channel mapping" , "Cumulative grouped fixed-length channel mapping", 
#                "Global cumulative mapping", "Global cumulative grouped variable-length channel mapping" , "Global cumulative grouped fixed-length channel mapping"]
# classifier_accuracies = [
#     # 5p
#     [0.845, 0.834, 0.851, 
#      0.844, 0.843, 0.852, 
#      0.844, 0.842, 0.852], # ROCKET
#     [0.825, 0.847, 0.851, 
#      0.848, 0.846, 0.843, 
#      0.850, 0.848, 0.857], # MiniROCKET
#     [0.826, 0.815, 0.840, 
#      0.810, 0.821, 0.831, 
#      0.819, 0.840, 0.831], # MultiROCKET
#     [0.848, 0.832, 0.843, 
#      0.850, 0.838, 0.855, 
#      0.849, 0.848, 0.858], # Hydra
#     [0.828, 0.817, 0.842, 
#      0.817, 0.827, 0.829, 
#      0.824, 0.839, 0.839], # MultiROCKET-Hydra
#      # 3p
#     [0.859, 0.852, 0.864, 
#      0.862, 0.853, 0.872, 
#      0.862, 0.853, 0.874], # ROCKET
#     [0.827, 0.828, 0.828, 
#      0.845, 0.838, 0.839, 
#      0.850, 0.848, 0.842], # MiniROCKET
#     [0.844, 0.827, 0.828, 
#      0.852, 0.825, 0.817, 
#      0.848, 0.831, 0.823], # MultiROCKET
#     [0.842, 0.814, 0.859, 
#      0.853, 0.826, 0.857, 
#      0.855, 0.819, 0.866], # Hydra
#     [0.834, 0.830, 0.831, 
#      0.855, 0.834, 0.828, 
#      0.853, 0.830, 0.828], # MultiROCKET-Hydra
#     # multi
#     [0.851, 0.846, 0.850, 
#      0.853, 0.852, 0.865, 
#      0.853, 0.855, 0.864], # ROCKET
#     [0.835, 0.830, 0.843, 
#      0.842, 0.845, 0.845, 
#      0.836, 0.848, 0.849], # MiniROCKET
#     [0.812, 0.817, 0.826, 
#      0.824, 0.827, 0.820, 
#      0.825, 0.822, 0.819], # MultiROCKET
#     [0.832, 0.818, 0.847, 
#      0.844, 0.829, 0.850, 
#      0.841, 0.822, 0.820], # Hydra
#     [0.818, 0.823, 0.834, 
#      0.835, 0.835, 0.831, 
#      0.832, 0.832, 0.820], # MultiROCKET-Hydra
# ]
# _ = plot_critical_difference(classifier_accuracies, classifiers)

# %%
import datetime
print(f"This Notebook last end-to-end runs on: {datetime.datetime.now()}\n")
###
###
###
# Out:
# This Notebook last end-to-end runs on: 2025-07-09 18:38:03.962030
